# %% [markdown]
# # Question 1: Use yfinance to Extract Stock Data (Tesla)

# %%
import yfinance as yf

# Download Tesla stock data
tesla_data = yf.download('TSLA', start='2010-01-01', end='2025-01-01')

# Reset index and display first 5 rows
tesla_data_reset = tesla_data.reset_index()
tesla_data_reset.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price        Date     Close      High       Low      Open     Volume
# Ticker                 TSLA      TSLA      TSLA      TSLA       TSLA
# 0      2010-06-29  1.592667  1.666667  1.169333  1.266667  281494500
# 1      2010-06-30  1.588667  2.028000  1.553333  1.719333  257806500
# 2      2010-07-01  1.464000  1.728000  1.351333  1.666667  123282000
# 3      2010-07-02  1.280000  1.540000  1.247333  1.533333   77097000
# 4      2010-07-06  1.074000  1.333333  1.055333  1.333333  103003500

# %% [markdown]
# # Question 2: Use Webscraping to Extract Tesla Revenue Data

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL of Tesla's financial data
url = 'https://finance.yahoo.com/quote/TSLA/financials'

# Send a request to the webpage and get the HTML content
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# Find the revenue data table
revenue_table = soup.find_all('table')[0]  # Adjust index as necessary

# Extracting data into a DataFrame
rows = revenue_table.find_all('tr')
data = []
for row in rows:
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

# Convert to DataFrame
tesla_revenue = pd.DataFrame(data[1:], columns=['Fiscal Year', 'Revenue'])
tesla_revenue.tail()
# Out:
# Empty DataFrame
# Columns: [Fiscal Year, Revenue]
# Index: []

# %% [markdown]
# # Question 4: Use Webscraping to Extract GME Revenue Data

# %%
# URL of GameStop's financial data
url_gme = 'https://finance.yahoo.com/quote/GME/financials'

# Send a request to the webpage and get the HTML content
response_gme = requests.get(url_gme)
soup_gme = BeautifulSoup(response_gme.text, 'html.parser')

# Find the revenue data table
revenue_table_gme = soup_gme.find_all('table')[0]  # Adjust index as necessary

# Extracting data into a DataFrame
rows_gme = revenue_table_gme.find_all('tr')
data_gme = []
for row in rows_gme:
    cols = row.find_all('td')
    data_gme.append([col.text.strip() for col in cols])

# Convert to DataFrame
gme_revenue = pd.DataFrame(data_gme[1:], columns=['Fiscal Year', 'Revenue'])
gme_revenue.tail()
# Out:
# Empty DataFrame
# Columns: [Fiscal Year, Revenue]
# Index: []

# %% [markdown]
# # Question 5: Plot Tesla Stock Graph

# %%
import matplotlib.pyplot as plt

# Plot Tesla stock data
def make_graph(data, title):
    plt.figure(figsize=(10, 6))
    plt.plot(data['Date'], data['Close'])
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel('Stock Price')
    plt.grid(True)
    plt.show()

make_graph(tesla_data_reset, 'Tesla Stock Price')

# %% [markdown]
# # Question 6: Plot GameStop Stock Graph

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# Step 1: Download GameStop stock data
gme_data = yf.download('GME', start='2010-01-01', end='2025-01-01')

# Step 2: Reset the index and store it in 'gme_data_reset'
gme_data_reset = gme_data.reset_index()

# Step 3: Define the make_graph function to plot the data
def make_graph(data, title):
    plt.figure(figsize=(10, 6))
    plt.plot(data['Date'], data['Close'])
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel('Stock Price')
    plt.grid(True)
    plt.show()

# Step 4: Call the make_graph function to plot GameStop stock price
make_graph(gme_data_reset, 'GameStop Stock Price')
# Out:
# [*********************100%***********************]  1 of 1 completed
